# %%
from massive import RESTClient
from datetime import datetime, timedelta
import json
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
from io import BytesIO
import boto3

s3 = boto3.client("s3")

client = RESTClient(api_key="0hPh9qhwsuN_DRbw8eWhndvA6Xtwdm12")
TICKERS = ["AAPL"]
#TICKERS = ["AAPL", "GOOGL", "MSFT", "AMZN", "TSLA"]

records = []
for ticker in TICKERS:
    

    resp = client.get_previous_close_agg(ticker)
    ts = datetime.fromtimestamp(resp[0].timestamp/1000).strftime("%Y-%m-%d")
    data = {"ticker":resp[0].ticker,
            "close":resp[0].close,
            "high":resp[0].high,
            "low":resp[0].low,
            "open":resp[0].open,
            "date":ts,
            "volume":resp[0].volume,
            "vwap":resp[0].vwap
            }
    
    records.append(data)


df = pd.DataFrame(records)

table = pa.Table.from_pandas(df, preserve_index=False)

buffer = BytesIO()
pq.write_table(table, buffer)

BUCKET = "stock-market-pipeline-bronze-dev"
KEY = f"daily-stock-data/date={ts}/stocks.parquet"

s3.put_object(
    Bucket=BUCKET,
    Key=KEY,
    Body=buffer.getvalue()
)
# Out:
# {'ResponseMetadata': {'RequestId': 'Y4DQHX5CPDAHR9Y0',
#   'HostId': 'up6t1Gl62YjbGgH/j0Ghjimoy0cdG1Tsel0fq6EN/1tuNFJ3XaDLJuJzVYoCNmgFNKHDCUSIeOmAQRXhrQggiKAMqvrV4UFT',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'up6t1Gl62YjbGgH/j0Ghjimoy0cdG1Tsel0fq6EN/1tuNFJ3XaDLJuJzVYoCNmgFNKHDCUSIeOmAQRXhrQggiKAMqvrV4UFT',
#    'x-amz-request-id': 'Y4DQHX5CPDAHR9Y0',
#    'date': 'Mon, 08 Jun 2026 10:06:14 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"af669df64da63fb9676479d843371158"',
#    'x-amz-checksum-crc64nvme': 'OrZK1pfWfU4=',
#    'x-amz-checksum-type': 'FULL_OBJECT',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"af669df64da63fb9676479d843371158"',
#  'ServerSideEncryption': 'AES256'}

# %%
# Out:
# Collecting pyarrow
#   Downloading pyarrow-21.0.0-cp39-cp39-win_amd64.whl.metadata (3.4 kB)
# Downloading pyarrow-21.0.0-cp39-cp39-win_amd64.whl (26.2 MB)
#    ---------------------------------------- 0.0/26.2 MB ? eta -:--:--
#    ---- ----------------------------------- 3.1/26.2 MB 16.8 MB/s eta 0:00:02
#    ------------------- -------------------- 12.8/26.2 MB 32.2 MB/s eta 0:00:01
#    -------------------------------- ------- 21.5/26.2 MB 35.7 MB/s eta 0:00:01
#    -------------------------------------- - 25.4/26.2 MB 32.2 MB/s eta 0:00:01
#    ---------------------------------------- 26.2/26.2 MB 28.2 MB/s eta 0:00:00
# Installing collected packages: pyarrow
# Successfully installed pyarrow-21.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 26.0.1
# [notice] To update, run: C:\Users\ARUN\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pd.DataFrame(records)

parquet_buffer = BytesIO()

df.to_parquet(parquet_buffer,engine="pyarrow",index=False)

s3.put_object(Bucket= ,Key= ,Body=parquet_buffer.getvalue())
# Out:
#   ticket   close    high     low    open        date      volume      vwap
# 0   AAPL  307.34  315.17  307.15  312.86  2026-06-06  65310502.0  310.4395
